# %%
#Import the necessary libraries
import pandas as pd

# %%
# Create an example dataframe about a fictional army
raw_data = {'regiment': ['Nighthawks', 'Nighthawks', 'Nighthawks', 'Nighthawks', 'Dragoons', 'Dragoons', 'Dragoons', 'Dragoons', 'Scouts', 'Scouts', 'Scouts', 'Scouts'],
            'company': ['1st', '1st', '2nd', '2nd', '1st', '1st', '2nd', '2nd','1st', '1st', '2nd', '2nd'],
            'deaths': [523, 52, 25, 616, 43, 234, 523, 62, 62, 73, 37, 35],
            'battles': [5, 42, 2, 2, 4, 7, 8, 3, 4, 7, 8, 9],
            'size': [1045, 957, 1099, 1400, 1592, 1006, 987, 849, 973, 1005, 1099, 1523],
            'veterans': [1, 5, 62, 26, 73, 37, 949, 48, 48, 435, 63, 345],
            'readiness': [1, 2, 3, 3, 2, 1, 2, 3, 2, 1, 2, 3],
            'armored': [1, 0, 1, 1, 0, 1, 0, 1, 0, 0, 1, 1],
            'deserters': [4, 24, 31, 2, 3, 4, 24, 31, 2, 3, 2, 3],
            'origin': ['Arizona', 'California', 'Texas', 'Florida', 'Maine', 'Iowa', 'Alaska', 'Washington', 'Oregon', 'Wyoming', 'Louisana', 'Georgia']}

# %%
#Create a dataframe and assign it to a variable called army.
army = pd.DataFrame(raw_data)
army
# Out:
#       regiment company  deaths  battles  size  veterans  readiness  armored  \
# 0   Nighthawks     1st     523        5  1045         1          1        1
# 1   Nighthawks     1st      52       42   957         5          2        0
# 2   Nighthawks     2nd      25        2  1099        62          3        1
# 3   Nighthawks     2nd     616        2  1400        26          3        1
# 4     Dragoons     1st      43        4  1592        73          2        0
# 5     Dragoons     1st     234        7  1006        37          1        1
# 6     Dragoons     2nd     523        8   987       949          2        0
# 7     Dragoons     2nd      62        3   849        48          3        1
# 8       Scouts     1st      62        4   973        48          2        0
# 9       Scouts     1st      73        7  1005       435          1        0
# 10      Scouts     2nd      37        8  1099        63          2        1
# 11      Scouts     2nd      35        9  1523       345          3        1
#
#     deserters      origin
# 0           4     Arizona
# 1          24  California
# 2          31       Texas
# 3           2     Florida
# 4           3       Maine
# 5           4        Iowa
# 6          24      Alaska
# 7          31  Washington
# 8           2      Oregon
# 9           3     Wyoming
# 10          2    Louisana
# 11          3     Georgia

# %%
#Set the 'origin' colum as the index of the dataframe
army.set_index("regiment")
# Out:
#            company  deaths  battles  size  veterans  readiness  armored  \
# regiment
# Nighthawks     1st     523        5  1045         1          1        1
# Nighthawks     1st      52       42   957         5          2        0
# Nighthawks     2nd      25        2  1099        62          3        1
# Nighthawks     2nd     616        2  1400        26          3        1
# Dragoons       1st      43        4  1592        73          2        0
# Dragoons       1st     234        7  1006        37          1        1
# Dragoons       2nd     523        8   987       949          2        0
# Dragoons       2nd      62        3   849        48          3        1
# Scouts         1st      62        4   973        48          2        0
# Scouts         1st      73        7  1005       435          1        0
# Scouts         2nd      37        8  1099        63          2        1
# Scouts         2nd      35        9  1523       345          3        1
#
#             deserters      origin
# regiment
# Nighthawks          4     Arizona
# Nighthawks         24  California
# Nighthawks         31       Texas
# Nighthawks          2     Florida
# Dragoons            3       Maine
# Dragoons            4        Iowa
# Dragoons           24      Alaska
# Dragoons           31  Washington
# Scouts              2      Oregon
# Scouts              3     Wyoming
# Scouts              2    Louisana
# Scouts              3     Georgia

# %%
#Print only the column veterans
army["veterans"]
# Out:
# 0       1
# 1       5
# 2      62
# 3      26
# 4      73
# 5      37
# 6     949
# 7      48
# 8      48
# 9     435
# 10     63
# 11    345
# Name: veterans, dtype: int64

# %%
#Print the columns 'veterans' and 'deaths'
army[["veterans","deaths"]]
# Out:
#     veterans  deaths
# 0          1     523
# 1          5      52
# 2         62      25
# 3         26     616
# 4         73      43
# 5         37     234
# 6        949     523
# 7         48      62
# 8         48      62
# 9        435      73
# 10        63      37
# 11       345      35

# %%
# Print the name of all the columns.
army.columns
# Out:
# Index(['regiment', 'company', 'deaths', 'battles', 'size', 'veterans',
#        'readiness', 'armored', 'deserters', 'origin'],
#       dtype='object')

# %%
#Select the 'deaths', 'size' and 'deserters' columns from Maine and Alaska
selected_cplomns = army[["deaths","size","deserters","origin"]]
origin_list = ["Maine","Alaska"]
selected_cplomns[selected_cplomns["origin"].isin(origin_list)]
# Out:
#    deaths  size  deserters  origin
# 4      43  1592          3   Maine
# 6     523   987         24  Alaska

# %%
#Select the rows 3 to 7 and the columns 3 to 6
army.iloc[3:8, 3:7]
# Out:
#    battles  size  veterans  readiness
# 3        2  1400        26          3
# 4        4  1592        73          2
# 5        7  1006        37          1
# 6        8   987       949          2
# 7        3   849        48          3

# %%
#Select every row after the fourth row and all columns
army.iloc[5:, : ]
# Out:
#     regiment company  deaths  battles  size  veterans  readiness  armored  \
# 5   Dragoons     1st     234        7  1006        37          1        1
# 6   Dragoons     2nd     523        8   987       949          2        0
# 7   Dragoons     2nd      62        3   849        48          3        1
# 8     Scouts     1st      62        4   973        48          2        0
# 9     Scouts     1st      73        7  1005       435          1        0
# 10    Scouts     2nd      37        8  1099        63          2        1
# 11    Scouts     2nd      35        9  1523       345          3        1
#
#     deserters      origin
# 5           4        Iowa
# 6          24      Alaska
# 7          31  Washington
# 8           2      Oregon
# 9           3     Wyoming
# 10          2    Louisana
# 11          3     Georgia

# %%
#Select every row up to the 4th row and all columns
army.iloc[:4, : ]
# Out:
#      regiment company  deaths  battles  size  veterans  readiness  armored  \
# 0  Nighthawks     1st     523        5  1045         1          1        1
# 1  Nighthawks     1st      52       42   957         5          2        0
# 2  Nighthawks     2nd      25        2  1099        62          3        1
# 3  Nighthawks     2nd     616        2  1400        26          3        1
#
#    deserters      origin
# 0          4     Arizona
# 1         24  California
# 2         31       Texas
# 3          2     Florida

# %%
#Select the 3rd column up to the 7th column
army.iloc[:, 3:8]
# Out:
#     battles  size  veterans  readiness  armored
# 0         5  1045         1          1        1
# 1        42   957         5          2        0
# 2         2  1099        62          3        1
# 3         2  1400        26          3        1
# 4         4  1592        73          2        0
# 5         7  1006        37          1        1
# 6         8   987       949          2        0
# 7         3   849        48          3        1
# 8         4   973        48          2        0
# 9         7  1005       435          1        0
# 10        8  1099        63          2        1
# 11        9  1523       345          3        1

# %%
#Select rows where df.deaths is greater than 50
army[army["deaths"]>50]
# Out:
#      regiment company  deaths  battles  size  veterans  readiness  armored  \
# 0  Nighthawks     1st     523        5  1045         1          1        1
# 1  Nighthawks     1st      52       42   957         5          2        0
# 3  Nighthawks     2nd     616        2  1400        26          3        1
# 5    Dragoons     1st     234        7  1006        37          1        1
# 6    Dragoons     2nd     523        8   987       949          2        0
# 7    Dragoons     2nd      62        3   849        48          3        1
# 8      Scouts     1st      62        4   973        48          2        0
# 9      Scouts     1st      73        7  1005       435          1        0
#
#    deserters      origin
# 0          4     Arizona
# 1         24  California
# 3          2     Florida
# 5          4        Iowa
# 6         24      Alaska
# 7         31  Washington
# 8          2      Oregon
# 9          3     Wyoming

# %%
# Select rows where df.deaths is greater than 500 or less than 50
army[(army["deaths"]>500) | (army["deaths"]<50)]
# Out:
#       regiment company  deaths  battles  size  veterans  readiness  armored  \
# 0   Nighthawks     1st     523        5  1045         1          1        1
# 2   Nighthawks     2nd      25        2  1099        62          3        1
# 3   Nighthawks     2nd     616        2  1400        26          3        1
# 4     Dragoons     1st      43        4  1592        73          2        0
# 6     Dragoons     2nd     523        8   987       949          2        0
# 10      Scouts     2nd      37        8  1099        63          2        1
# 11      Scouts     2nd      35        9  1523       345          3        1
#
#     deserters    origin
# 0           4   Arizona
# 2          31     Texas
# 3           2   Florida
# 4           3     Maine
# 6          24    Alaska
# 10          2  Louisana
# 11          3   Georgia

# %%
#Select all the regiments not named "Dragoons"
army[army["regiment"] == "Dragoons"]
# Out:
#    regiment company  deaths  battles  size  veterans  readiness  armored  \
# 4  Dragoons     1st      43        4  1592        73          2        0
# 5  Dragoons     1st     234        7  1006        37          1        1
# 6  Dragoons     2nd     523        8   987       949          2        0
# 7  Dragoons     2nd      62        3   849        48          3        1
#
#    deserters      origin
# 4          3       Maine
# 5          4        Iowa
# 6         24      Alaska
# 7         31  Washington

# %%
#Select the rows called Texas and Arizona
row= ["Texas", "Arizona"]
army_origin = army[army["origin"].isin(row)]
army_origin
# Out:
#      regiment company  deaths  battles  size  veterans  readiness  armored  \
# 0  Nighthawks     1st     523        5  1045         1          1        1
# 2  Nighthawks     2nd      25        2  1099        62          3        1
#
#    deserters   origin
# 0          4  Arizona
# 2         31    Texas

# %%
#Select the third cell in the row named Arizona
army_origin.iloc[:1, 2:3]
# Out:
#    deaths
# 0     523

# %%
#Select the third cell down in the column named deaths
army.deaths.iloc[-3:-2]
# Out:
# 9    73
# Name: deaths, dtype: int64
